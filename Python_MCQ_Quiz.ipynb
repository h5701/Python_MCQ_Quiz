# %% [markdown]
# <a href="https://colab.research.google.com/github/h5701/Python_MCQ_Quiz/blob/main/Python_MCQ_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sports_quiz():
    questions = [
        {"question": "Which sport is known as the 'king of sports'?", "options": ["A. Football", "B. Basketball", "C. Cricket", "D. Tennis"], "answer": "A"},
        {"question": "How many players are there in a soccer team on the field?", "options": ["A. 11", "B. 10", "C. 9", "D. 12"], "answer": "A"},
        {"question": "Which country won the FIFA World Cup in 2018?", "options": ["A. Germany", "B. Brazil", "C. France", "D. Argentina"], "answer": "C"},
        {"question": "In tennis, what is the term for a score of zero?", "options": ["A. Love", "B. Zero", "C. Nil", "D. Blank"], "answer": "A"},
        {"question": "Which athlete is known as 'Lightning Bolt'?", "options": ["A. Carl Lewis", "B. Usain Bolt", "C. Michael Johnson", "D. Jesse Owens"], "answer": "B"},
        {"question": "Which sport uses a shuttlecock?", "options": ["A. Badminton", "B. Squash", "C. Tennis", "D. Volleyball"], "answer": "A"},
        {"question": "How many rings are there on the Olympic flag?", "options": ["A. 4", "B. 5", "C. 6", "D. 7"], "answer": "B"},
        {"question": "What sport is Michael Jordan famous for?", "options": ["A. Football", "B. Baseball", "C. Basketball", "D. Hockey"], "answer": "C"},
        {"question": "In which sport would you perform a slam dunk?", "options": ["A. Volleyball", "B. Basketball", "C. Football", "D. Tennis"], "answer": "B"},
        {"question": "Which country hosts the Grand Prix F1 race?", "options": ["A. Monaco", "B. Japan", "C. USA", "D. Australia"], "answer": "A"},
    ]
    return ask_questions(questions)

def shakespeare_quiz():
    questions = [
        {"question": "Who wrote 'Hamlet'?", "options": ["A. William Shakespeare", "B. Christopher Marlowe", "C. Ben Jonson", "D. John Donne"], "answer": "A"},
        {"question": "Which play features the characters Oberon and Titania?", "options": ["A. Macbeth", "B. A Midsummer Night's Dream", "C. Romeo and Juliet", "D. The Tempest"], "answer": "B"},
        {"question": "Finish the line: 'To be, or not to be, that is the ____.'", "options": ["A. Question", "B. Answer", "C. Problem", "D. Dilemma"], "answer": "A"},
        {"question": "Which play is about the star-crossed lovers Romeo and Juliet?", "options": ["A. Othello", "B. Romeo and Juliet", "C. Julius Caesar", "D. King Lear"], "answer": "B"},
        {"question": "What is the setting of 'Macbeth'?", "options": ["A. England", "B. Scotland", "C. Ireland", "D. Wales"], "answer": "B"},
        {"question": "Who is the tragic hero in 'Othello'?", "options": ["A. Iago", "B. Cassio", "C. Othello", "D. Desdemona"], "answer": "C"},
        {"question": "Which Shakespeare play features the line 'All the world's a stage'?", "options": ["A. As You Like It", "B. Hamlet", "C. The Tempest", "D. Twelfth Night"], "answer": "A"},
        {"question": "Which comedy is set on the island of Illyria?", "options": ["A. Twelfth Night", "B. The Merchant of Venice", "C. Much Ado About Nothing", "D. The Comedy of Errors"], "answer": "A"},
        {"question": "Which play ends with the marriage of multiple couples?", "options": ["A. A Midsummer Night's Dream", "B. Macbeth", "C. Hamlet", "D. King Lear"], "answer": "A"},
        {"question": "What is the name of Romeo’s cousin?", "options": ["A. Mercutio", "B. Tybalt", "C. Benvolio", "D. Paris"], "answer": "C"},
    ]
    return ask_questions(questions)

def maths_quiz():
    questions = [
        {"question": "What is 7 x 8?", "options": ["A. 54", "B. 56", "C. 58", "D. 60"], "answer": "B"},
        {"question": "What is the square root of 81?", "options": ["A. 7", "B. 8", "C. 9", "D. 10"], "answer": "C"},
        {"question": "What is 15% of 200?", "options": ["A. 20", "B. 25", "C. 30", "D. 35"], "answer": "C"},
        {"question": "What is the next prime number after 7?", "options": ["A. 9", "B. 10", "C. 11", "D. 13"], "answer": "C"},
        {"question": "What is 12 squared?", "options": ["A. 124", "B. 144", "C. 134", "D. 154"], "answer": "B"},
        {"question": "What is the value of Pi (π) rounded to 2 decimals?", "options": ["A. 3.12", "B. 3.14", "C. 3.16", "D. 3.18"], "answer": "B"},
        {"question": "Solve for x: 2x + 6 = 14", "options": ["A. 2", "B. 3", "C. 4", "D. 5"], "answer": "C"},
        {"question": "What is 100 divided by 4?", "options": ["A. 20", "B. 25", "C. 30", "D. 35"], "answer": "B"},
        {"question": "What is 5 factorial (5!)?", "options": ["A. 100", "B. 120", "C. 140", "D. 150"], "answer": "B"},
        {"question": "How many degrees are in a right angle?", "options": ["A. 45", "B. 60", "C. 90", "D. 180"], "answer": "C"},
    ]
    return ask_questions(questions)

def general_knowledge_quiz():
    questions = [
        {"question": "Which ocean is the largest?", "options": ["A. Atlantic", "B. Indian", "C. Pacific", "D. Arctic"], "answer": "C"},
        {"question": "Who painted the Mona Lisa?", "options": ["A. Picasso", "B. Van Gogh", "C. Da Vinci", "D. Michelangelo"], "answer": "C"},
        {"question": "Which country hosted the 2020 Summer Olympics?", "options": ["A. China", "B. Japan", "C. Brazil", "D. UK"], "answer": "B"},
        {"question": "What is the hardest natural substance?", "options": ["A. Gold", "B. Iron", "C. Diamond", "D. Quartz"], "answer": "C"},
        {"question": "How many continents are there?", "options": ["A. 5", "B. 6", "C. 7", "D. 8"], "answer": "C"},
        {"question": "What is the capital of Australia?", "options": ["A. Sydney", "B. Canberra", "C. Melbourne", "D. Brisbane"], "answer": "B"},
        {"question": "Which language is the most spoken worldwide?", "options": ["A. English", "B. Mandarin", "C. Spanish", "D. Hindi"], "answer": "B"},
        {"question": "What is the chemical symbol for gold?", "options": ["A. Ag", "B. Au", "C. Gd", "D. Go"], "answer": "B"},
        {"question": "Which planet is closest to the sun?", "options": ["A. Venus", "B. Mars", "C. Mercury", "D. Earth"], "answer": "C"},
        {"question": "Who discovered penicillin?", "options": ["A. Marie Curie", "B. Alexander Fleming", "C. Isaac Newton", "D. Albert Einstein"], "answer": "B"},
    ]
    return ask_questions(questions)

def science_quiz():
    questions = [
        {"question": "What gas do plants absorb from the atmosphere?", "options": ["A. Oxygen", "B. Carbon Dioxide", "C. Nitrogen", "D. Hydrogen"], "answer": "B"},
        {"question": "What is H2O commonly known as?", "options": ["A. Salt", "B. Water", "C. Oxygen", "D. Hydrogen"], "answer": "B"},
        {"question": "What planet is known as the Red Planet?", "options": ["A. Venus", "B. Mars", "C. Jupiter", "D. Saturn"], "answer": "B"},
        {"question": "What force keeps us on the ground?", "options": ["A. Magnetism", "B. Gravity", "C. Friction", "D. Electricity"], "answer": "B"},
        {"question": "What part of the cell contains genetic material?", "options": ["A. Cytoplasm", "B. Nucleus", "C. Membrane", "D. Mitochondria"], "answer": "B"},
        {"question": "What is the speed of light?", "options": ["A. 300,000 km/s", "B. 150,000 km/s", "C. 100,000 km/s", "D. 250,000 km/s"], "answer": "A"},
        {"question": "What gas do humans breathe in to survive?", "options": ["A. Nitrogen", "B. Carbon Dioxide", "C. Oxygen", "D. Helium"], "answer": "C"},
        {"question": "What is the chemical formula for table salt?", "options": ["A. NaCl", "B. KCl", "C. CaCO3", "D. H2SO4"], "answer": "A"},
        {"question": "What organ pumps blood throughout the body?", "options": ["A. Brain", "B. Liver", "C. Heart", "D. Lung"], "answer": "C"},
        {"question": "What type of energy comes from the sun?", "options": ["A. Nuclear", "B. Solar", "C. Wind", "D. Thermal"], "answer": "B"},
    ]
    return ask_questions(questions)

def history_quiz():
    questions = [
        {"question": "Who was the first President of the United States?", "options": ["A. Thomas Jefferson", "B. George Washington", "C. Abraham Lincoln", "D. John Adams"], "answer": "B"},
        {"question": "In which year did World War II end?", "options": ["A. 1945", "B. 1940", "C. 1939", "D. 1950"], "answer": "A"},
        {"question": "Which empire built the Colosseum?", "options": ["A. Greek", "B. Roman", "C. Egyptian", "D. Persian"], "answer": "B"},
        {"question": "Who was known as the 'Maid of Orleans'?", "options": ["A. Joan of Arc", "B. Marie Antoinette", "C. Cleopatra", "D. Catherine the Great"], "answer": "A"},
        {"question": "What wall divided East and West Berlin?", "options": ["A. Great Wall", "B. Berlin Wall", "C. Hadrian’s Wall", "D. Wall of China"], "answer": "B"},
        {"question": "Who discovered America in 1492?", "options": ["A. Christopher Columbus", "B. Vasco da Gama", "C. Ferdinand Magellan", "D. James Cook"], "answer": "A"},
        {"question": "Which revolution began in 1789?", "options": ["A. American", "B. Russian", "C. French", "D. Industrial"], "answer": "C"},
        {"question": "Who was the British Prime Minister during WWII?", "options": ["A. Winston Churchill", "B. Neville Chamberlain", "C. Tony Blair", "D. Margaret Thatcher"], "answer": "A"},
        {"question": "The Renaissance began in which country?", "options": ["A. France", "B. Italy", "C. Germany", "D. Spain"], "answer": "B"},
        {"question": "Who was the first man to step on the moon?", "options": ["A. Yuri Gagarin", "B. Buzz Aldrin", "C. Neil Armstrong", "D. Michael Collins"], "answer": "C"},
    ]
    return ask_questions(questions)

def ask_questions(questions):
    score = 0
    for idx, q in enumerate(questions, 1):
        print(f"\nQ{idx}: {q['question']}")
        for option in q['options']:
            print(option)
        while True:
            answer = input("Your answer (A/B/C/D): ").strip().upper()
            if answer in ['A', 'B', 'C', 'D']:
                break
            print("Invalid choice, please enter A, B, C, or D.")
        if answer == q['answer']:
            print("Correct!")
            score += 1
        else:
            print(f"Wrong! The correct answer was {q['answer']}.")
    return score

def main():
    print("Welcome to the Quiz Game!")
    name = input("Please enter your name: ").strip()
    categories = {
        "1": ("Sports", sports_quiz),
        "2": ("Shakespeare", shakespeare_quiz),
        "3": ("Maths", maths_quiz),
        "4": ("General Knowledge", general_knowledge_quiz),
        "5": ("Science", science_quiz),
        "6": ("History", history_quiz)
    }

    print("\nSelect a category:")
    for key, (cat_name, _) in categories.items():
        print(f"{key}. {cat_name}")

    while True:
        choice = input("Enter the number of your choice: ").strip()
        if choice in categories:
            break
        print("Invalid choice, please enter a valid number from the list.")

    category_name, quiz_function = categories[choice]
    print(f"\n{name}, you have selected '{category_name}'. Let's start!\n")
    score = quiz_function()

    print(f"\n{name}, you have scored {score} out of 10. Thanks for playing!")

if __name__ == "__main__":
    main()
